# %%
import pandas as pd

# %%
df = pd.read_csv("../data/bls.gov/employment/raw/01.csv", delimiter='\t')
df.head()
# Out:
#               series_id   state                 area  year period      month  \
# 0  SMU15279803000000001  Hawaii  Kahului-Wailuku, HI  2025    M12   December
# 1  SMU15279803000000001  Hawaii  Kahului-Wailuku, HI  2025    M11   November
# 2  SMU15279803000000001  Hawaii  Kahului-Wailuku, HI  2025    M10    October
# 3  SMU15279803000000001  Hawaii  Kahului-Wailuku, HI  2025    M09  September
# 4  SMU15279803000000001  Hawaii  Kahului-Wailuku, HI  2025    M08     August
#
#    value
# 0    1.1
# 1    1.1
# 2    1.1
# 3    1.1
# 4    1.1

# %%
len(set(df.area))
# Out:
# 392

# %%
df.rename(columns={'value':'total_workers'}, inplace=True)
df.head()
# Out:
#               series_id   state                 area  year period      month  \
# 0  SMU15279803000000001  Hawaii  Kahului-Wailuku, HI  2025    M12   December
# 1  SMU15279803000000001  Hawaii  Kahului-Wailuku, HI  2025    M11   November
# 2  SMU15279803000000001  Hawaii  Kahului-Wailuku, HI  2025    M10    October
# 3  SMU15279803000000001  Hawaii  Kahului-Wailuku, HI  2025    M09  September
# 4  SMU15279803000000001  Hawaii  Kahului-Wailuku, HI  2025    M08     August
#
#    total_workers
# 0            1.1
# 1            1.1
# 2            1.1
# 3            1.1
# 4            1.1

# %%
df.total_workers = df.total_workers * 1000

# %%
df.head(3)
# Out:
#               series_id   state                 area  year period     month  \
# 0  SMU15279803000000001  Hawaii  Kahului-Wailuku, HI  2025    M12  December
# 1  SMU15279803000000001  Hawaii  Kahului-Wailuku, HI  2025    M11  November
# 2  SMU15279803000000001  Hawaii  Kahului-Wailuku, HI  2025    M10   October
#
#    total_workers
# 0         1100.0
# 1         1100.0
# 2         1100.0

# %%
df.dtypes
# Out:
# series_id         object
# state             object
# area              object
# year               int64
# period            object
# month             object
# total_workers    float64
# dtype: object

# %%
df.total_workers = df.total_workers.astype("int64")
df.head()
# Out:
#               series_id   state                 area  year period      month  \
# 0  SMU15279803000000001  Hawaii  Kahului-Wailuku, HI  2025    M12   December
# 1  SMU15279803000000001  Hawaii  Kahului-Wailuku, HI  2025    M11   November
# 2  SMU15279803000000001  Hawaii  Kahului-Wailuku, HI  2025    M10    October
# 3  SMU15279803000000001  Hawaii  Kahului-Wailuku, HI  2025    M09  September
# 4  SMU15279803000000001  Hawaii  Kahului-Wailuku, HI  2025    M08     August
#
#    total_workers
# 0           1100
# 1           1100
# 2           1100
# 3           1100
# 4           1100

# %%
df.describe()
# Out:
#                year  total_workers
# count  89376.000000   89376.000000
# mean    2016.000000   32653.523306
# std        5.477256   57352.965629
# min     2007.000000     400.000000
# 25%     2011.000000    5700.000000
# 50%     2016.000000   13500.000000
# 75%     2021.000000   31800.000000
# max     2025.000000  642200.000000

# %%
df2 = pd.read_csv("../data/bls.gov/employment/processed/01_5yr_perc_change.csv", index_col=0)
df2.head()
# Out:
#             state                             area  old_year  new_year  \
# 0  South Carolina                  Spartanburg, SC      2021      2025
# 1  South Carolina                  Spartanburg, SC      2016      2020
# 2  South Carolina                  Spartanburg, SC      2011      2015
# 3           Texas  Dallas-Fort Worth-Arlington, TX      2021      2025
# 4           Texas  Dallas-Fort Worth-Arlington, TX      2016      2020
#
#    old_number  new_number  perc_change
# 0        37.2        41.0     0.102151
# 1        29.9        37.0     0.237458
# 2        26.4        29.0     0.098485
# 3       292.6       307.6     0.051265
# 4       266.6       281.5     0.055889
